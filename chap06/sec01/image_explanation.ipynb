# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")  # 환경 변수에서 API 키를 가져오기

client = OpenAI(api_key=api_key)  # 오픈AI 클라이언트의 인스턴스 생성

messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "이 이미지에 대해 설명해주세요."},
            {
                "type": "image_url",
                "image_url": {
                    "url": "https://images.unsplash.com/photo-1736264335247-8ec5664c8328?q=80&w=1887&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model="gpt-4o",  # 응답 생성에 사용할 모델 지정
    messages=messages # 대화 기록을 입력으로 전달
)

response
# Out:
# ChatCompletion(id='chatcmpl-BwMAazK1rjNyGFxF38gUmuRqWidSB', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='이 이미지에는 한 여성이 주방에서 요리를 준비하고 있는 모습이 담겨 있습니다. 그녀는 검정색 운동복을 입고 있으며, 한 손에는 거품기를 들고 파란색 그릇 안의 재료를 섞고 있습니다. 옆에 있는 팬에서는 아마도 고기나 베이컨이 굽히고 있는 중입니다. 그녀는 활짝 웃고 있어 요리를 즐기고 있는 듯한 분위기를 연출하고 있습니다.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))], created=1753247944, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_a288987b44', usage=CompletionUsage(completion_tokens=102, prompt_tokens=1119, total_tokens=1221, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
import base64

# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")
    
image_path = "../data/images/mangwon_bakery.jpg"

# 이미지를 base64로 인코딩
base64_image = encode_image(image_path)

print(base64_image)
# Out:
# ...

# %%
messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "이 이미지에 대해 설명해주세요."},
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{base64_image}",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model="gpt-4o",  # 응답 생성에 사용할 모델 지정
    messages=messages # 대화 기록을 입력으로 전달
)

response.choices[0].message.content
# Out:
# '이 이미지는 제과점의 진열대입니다. 진열대에는 다양한 종류의 빵과 패스트리가 놓여져 있으며, 각각의 제품에는 가격이 적힌 작은 표지판이 있습니다. 빵들은 갓 구워진 것으로 보이며, 여러 가지 모양과 색상으로 다양하게 배열되어 있습니다. 진열대 뒤쪽에는 직원들이 있으며, 포장 작업이나 다른 업무를 하고 있는 모습입니다. 가게 내부는 깔끔하고 환한 조명 아래 정리된 상태로 보입니다.'

# %%
seolleung_terrarosa_base64 = encode_image("../data/images/seolleung_terrarosa.jpg")
local_stitch_terrarosa_base64 = encode_image("../data/images/local_stitch_terrarosa.jpg")

messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "두 카페의 차이점을 설명해주세요."},
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{seolleung_terrarosa_base64}",
                },
            },
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{local_stitch_terrarosa_base64}",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model="gpt-4o",  # 응답 생성에 사용할 모델 지정
    messages=messages # 대화 기록을 입력으로 전달
)

response.choices[0].message.content
# Out:
# '첫 번째 카페와 두 번째 카페의 차이점은 다음과 같습니다:\n\n1. **인테리어 스타일**:\n   - 첫 번째 카페는 어두운 색조의 천장과 나무 바닥으로 고급스럽고 아늑한 분위기를 갖추고 있습니다. 조명도 은은하게 설치되어 있어 편안한 환경을 제공합니다.\n   - 두 번째 카페는 밝은 벽과 천장을 사용해 현대적이고 깔끔한 느낌을 줍니다. 노란색 포인트 벽이 있으며, 전체적으로 밝은 조명 덕분에 활기찬 분위기를 느낄 수 있습니다.\n\n2. **가구 배치**:\n   - 첫 번째 카페는 넓고 여유로운 좌석 배치로, 서로의 공간이 잘 확보되어 있습니다. 여러 사람들이 앉아 이야기를 나누기에 적합한 구조입니다.\n   - 두 번째 카페는 테이블과 의자가 조밀하게 배치되어 있으며, 바도 있어 빠르고 간편한 서비스가 가능한 구조입니다. \n\n3. **공간 활용**:\n   - 첫 번째 카페는 넓은 공간을 활용해 다양한 유형의 좌석 및 테이블을 마련하였으며, 편안한 대화를 위한 분위기입니다.\n   - 두 번째 카페는 비교적 컴팩트한 공간에 여러 가지 서비스를 제공할 수 있도록 최적화되어 있습니다.\n\n이러한 차이점들이 각 카페의 독특한 특성을 표현하고 있습니다.'

# %%
oecd_rnd_2021_base64 = encode_image("../data/images/oecd_rnd_2021_large.png")
oecd_rnd_2022_base64 = encode_image("../data/images/oecd_rnd_2022_large.png")

messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "첫번째는 2021년 데이터이고, 두번째는 2022년 데이터입니다. 이 데이터에 대해 설명해주세요. 어떤 변화가 있었나요? 한국 중심으로 설명해주세요."},
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{oecd_rnd_2021_base64}",
                },
            },
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{oecd_rnd_2022_base64}",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model="gpt-4o",  # 응답 생성에 사용할 모델 지정
    messages=messages # 대화 기록을 입력으로 전달
)

response.choices[0].message.content
# Out:
# '이 두 그래프는 2021년과 2022년의 주요 국가별 연구개발비와 GDP 대비 연구개발비 비중을 보여줍니다. 한국을 중심으로 살펴보면 다음과 같은 변화가 있습니다:\n\n1. **연구개발비(억원 달러)**\n   - 2021년: 한국의 연구개발비는 약 89,282백만 USD였습니다.\n   - 2022년: 한국의 연구개발비는 약 91,013백만 USD로 증가했습니다.\n\n2. **GDP 대비 연구개발비 비중(%)**\n   - 2021년: 한국의 GDP 대비 연구개발비 비중은 4.93%였습니다.\n   - 2022년: 이는 약간 감소하여 4.91%로 나타났습니다.\n\n3. **변화 요약**\n   - 한국의 연구개발비는 금액적으로 증가했지만, GDP 대비 비중은 약간 감소하였습니다. 이는 GDP 성장률이 연구개발비 증가율보다 높았기 때문일 수 있습니다.\n\n이를 통해 한국은 지속적으로 연구개발에 투자를 늘리고 있지만, GDP의 성장으로 인해 비중 자체는 약간 감소한 것으로 볼 수 있습니다.'

# %%
oecd_rnd_2021_base64 = encode_image("../data/images/oecd_rnd_2021_medium.png")
oecd_rnd_2022_base64 = encode_image("../data/images/oecd_rnd_2022.png")

messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "첫번째는 2021년 데이터이고, 두번째는 2022년 데이터입니다. 이 데이터에 대해 설명해주세요. 어떤 변화가 있었나요? 한국 중심으로 설명해주세요."},
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{oecd_rnd_2021_base64}",
                },
            },
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{oecd_rnd_2022_base64}",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model="gpt-4o",  # 응답 생성에 사용할 모델 지정
    messages=messages # 대화 기록을 입력으로 전달
)

response.choices[0].message.content
# Out:
# '두 이미지에서 2021년과 2022년 데이터를 비교해보면 다음과 같은 한국 중심의 변화가 있습니다:\n\n1. **연구개발비**:\n   - 2021년: 1213억 9천만 달러\n   - 2022년: 872억 2천 5백만 달러\n   - 연구개발비가 감소한 것을 볼 수 있습니다.\n\n2. **GDP 대비 연구개발비 비중**:\n   - 2021년: 3.13%\n   - 2022년: 2.91%\n   - 경제 규모 대비 연구개발에 투자하는 비율도 약간 감소하였습니다.\n\n전체적인 흐름을 보면 한국의 연구개발비와 그 비중이 모두 감소한 것으로 나타나며, 이는 국가의 연구개발 투자가 줄어들었음을 시사합니다. \n\n환율의 변화로 인한 영향을 감안할 필요도 있으며, 다른 국가와의 비교를 통해 이러한 변화의 상대적인 의미를 파악할 수 있습니다.'
