# %%
# ========================= 코드 해설 주석 시작 =========================
# 이 셀의 역할(요약):
#  - pandas로 데이터프레임을 전처리/정리/표시합니다.
# 주의: 아래 주석은 원본 코드의 동작을 변경하지 않으며, 가독성을 위해 상단에만 추가되었습니다.
# 첫 줄 미리보기: 'import pandas as pd'
# ========================= 코드 해설 주석 끝 ===========================
import pandas as pd

meeting_note_csv_path = "../audio/싼기타_비싼기타_final.csv"
df_rttm = pd.read_csv(meeting_note_csv_path, sep='|')

display(df_rttm)
# Out:
#       start      end  speaker_id  duration  \
# 0     0.993   30.204  SPEAKER_01    29.211
# 1    32.414   42.708  SPEAKER_00    10.294
# 2    41.645   44.024  SPEAKER_01     2.379
# 3    45.813   67.109  SPEAKER_00    21.296
# 4    67.227   82.786  SPEAKER_01    15.559
# 5    84.659  102.564  SPEAKER_00    17.905
# 6   103.492  117.532  SPEAKER_01    14.040
# 7   119.759  138.676  SPEAKER_00    18.917
# 8   139.351  168.967  SPEAKER_01    29.616
# 9   170.907  192.321  SPEAKER_00    21.414
# 10  192.322  193.689  SPEAKER_01     1.367
# 11  192.760  193.503  SPEAKER_00     0.743
# 12  193.823  216.571  SPEAKER_01    22.748
# 13  218.579  238.120  SPEAKER_00    19.541
# 14  238.120  238.677  SPEAKER_01     0.557
# 15  238.188  239.352  SPEAKER_00     1.164
# 16  239.858  240.651  SPEAKER_01     0.793
# 17  240.297  241.006  SPEAKER_00     0.709
# 18  241.040  251.334  SPEAKER_01    10.294
# 19  253.696  271.550  SPEAKER_00    17.854
# 20  272.140  304.557  SPEAKER_01    32.417
# ...

# %%
# ========================= 코드 해설 주석 시작 =========================
# 이 셀의 역할(요약):
#  - 임포트/설정/헬퍼 등 보조 로직을 수행합니다.
# 주의: 아래 주석은 원본 코드의 동작을 변경하지 않으며, 가독성을 위해 상단에만 추가되었습니다.
# 첫 줄 미리보기: '# 이름 넣기'
# ========================= 코드 해설 주석 끝 ===========================
# 이름 넣기
name_dict = {
    "SPEAKER_00": "AI",
    "SPEAKER_01": "이형열",
}

df_rttm["name"] = df_rttm["speaker_id"].apply(lambda x: name_dict[x])

display(df_rttm)
# Out:
#       start      end  speaker_id  duration  \
# 0     0.993   30.204  SPEAKER_01    29.211
# 1    32.414   42.708  SPEAKER_00    10.294
# 2    41.645   44.024  SPEAKER_01     2.379
# 3    45.813   67.109  SPEAKER_00    21.296
# 4    67.227   82.786  SPEAKER_01    15.559
# 5    84.659  102.564  SPEAKER_00    17.905
# 6   103.492  117.532  SPEAKER_01    14.040
# 7   119.759  138.676  SPEAKER_00    18.917
# 8   139.351  168.967  SPEAKER_01    29.616
# 9   170.907  192.321  SPEAKER_00    21.414
# 10  192.322  193.689  SPEAKER_01     1.367
# 11  192.760  193.503  SPEAKER_00     0.743
# 12  193.823  216.571  SPEAKER_01    22.748
# 13  218.579  238.120  SPEAKER_00    19.541
# 14  238.120  238.677  SPEAKER_01     0.557
# 15  238.188  239.352  SPEAKER_00     1.164
# 16  239.858  240.651  SPEAKER_01     0.793
# 17  240.297  241.006  SPEAKER_00     0.709
# 18  241.040  251.334  SPEAKER_01    10.294
# 19  253.696  271.550  SPEAKER_00    17.854
# 20  272.140  304.557  SPEAKER_01    32.417
# ...

# %%
# ========================= 코드 해설 주석 시작 =========================
# 이 셀의 역할(요약):
#  - JSON/YAML로 결과를 직렬화하거나 로드/저장합니다.
# 주의: 아래 주석은 원본 코드의 동작을 변경하지 않으며, 가독성을 위해 상단에만 추가되었습니다.
# 첫 줄 미리보기: "meeting_note_txt = df_rttm[['start', 'end', 'name', 'text']].to_json(orient='records', force_ascii=False)"
# ========================= 코드 해설 주석 끝 ===========================
meeting_note_txt = df_rttm[['start', 'end', 'name', 'text']].to_json(orient='records', force_ascii=False)
print(meeting_note_txt)
# Out:
# [{"start":0.993,"end":30.204,"name":"이형열","text":"지금부터 저랑 역할극을 합시다.\n역할극을 스탠드인 코미디 스타일로 할 건데\n토론을 하면서 자연스럽게 대화하는 형식으로 하면서\n코미디를 진행해봅시다.\n그래서 좀 재밌고 자연스럽고 유머러스하게 저랑 대화를 하시면 돼요.\n자연스럽게.\n그리고 주제는 쌍기타로 전기기타를 시작하는 게 좋으냐\n아니면 비싼 기타로 전기기타를 시작하는 게 좋으냐\n이거를 입장을 나눠가지고\n저랑 토론해보면 좋을 것 같아요.\n어, 두 중에 어떤 역할 맡으실래요?\n"},{"start":32.414,"end":42.708,"name":"AI","text":"좋습니다. 그럼 제가 싼 기타로 시작하는게 좋다는 입장을 맡아볼게요. 그럼 성형님은 비싼 기타로 시작하는 게 좋다는 입장이시죠? 네 맞아요. 준비 되셨나요?\n"},{"start":41.645,"end":44.024,"name":"이형열","text":"네, 됐어요. 시작하시죠.\n"},{"start":45.813,"end":67.109,"name":"AI","text":"좋아요. 먼저 3기타로 시작하는 게 좋은 이유를 말씀드리겠습니다.\n초보자일 때는 실수도 많고 기타에 익숙해지는 과정이 필요하니까\n비싼 기타보다는 부담�없이 연습할 수 있는 싼 기타가 좋다고 봅니다.\n무엇보다 실력이 향상되면 그때 좋은 기타로 업그레이드 하는 것도 나쁘지 않죠?\n성형님은 어떻게 생각하세요?\n"},{"start":67.227,"end":82.786,"name":"이형열","text":"아, 저는 지금 말에 어폐가 있다고 생각해요.\n왜냐하면 어차피 지금 비싼 기타로\n나중에 살 생각을 하는 거잖아요.\n그럼 어차피 비싼 기타 사고 쌍기타 사게 되는데 그런 이중 이중 지출을 하지 말고 처음부터 비싼 기타로 가면은 이중지출을 하지 말고 처음부터 비싼 기타로 가면 이중지출을 막을 수가 있습니다.\n"},{"start":84.659,"end":102.56
# ...

# %%
# ========================= 코드 해설 주석 시작 =========================
# 이 셀의 역할(요약):
#  - 프롬프트 템플릿을 정의하거나 입력 변수를 채워 요청을 구성합니다.
# 주의: 아래 주석은 원본 코드의 동작을 변경하지 않으며, 가독성을 위해 상단에만 추가되었습니다.
# 첫 줄 미리보기: "system_prompt = f'''"
# ========================= 코드 해설 주석 끝 ===========================
system_prompt = f'''
너는 회의 내용을 요약하는 봇이다. 아래 회의록을 읽고, 주요 내용을 요약하라.
결과는 마크다운 형식으로 작성한다.

아래 형식에 맞추어 작성하라.

# 회의 제목

## 주요 내용

## 참석자별 입장

## 결정 사항   

=============== 이하 회의록 ===============

{ meeting_note_txt }
'''

# %%
# ========================= 코드 해설 주석 시작 =========================
# 이 셀의 역할(요약):
#  - OpenAI 호출(요약/교정/생성 등)을 수행하거나 응답을 파싱합니다.
#  - .env에서 API 키 등 환경 변수를 로드합니다.
# 주의: 아래 주석은 원본 코드의 동작을 변경하지 않으며, 가독성을 위해 상단에만 추가되었습니다.
# 첫 줄 미리보기: 'from openai import OpenAI'
# ========================= 코드 해설 주석 끝 ===========================
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')
client = OpenAI(api_key=api_key)

# %%
# ========================= 코드 해설 주석 시작 =========================
# 이 셀의 역할(요약):
#  - OpenAI 호출(요약/교정/생성 등)을 수행하거나 응답을 파싱합니다.
#  - 프롬프트 템플릿을 정의하거나 입력 변수를 채워 요청을 구성합니다.
# 주의: 아래 주석은 원본 코드의 동작을 변경하지 않으며, 가독성을 위해 상단에만 추가되었습니다.
# 첫 줄 미리보기: '# OpenAI API를 사용해 요약 결과 생성'
# ========================= 코드 해설 주석 끝 ===========================
# OpenAI API를 사용해 요약 결과 생성
response = client.chat.completions.create(
    model='gpt-4o',
    temperature=0.1,
    messages=[
        {"role": "system", "content": system_prompt},
    ]
)

# (4) 요약 결과를 파일로 저장
summary = response.choices[0].message.content 
summary = summary.strip() # 좌우 공백 제거

print(summary)
# Out:
# # 회의 제목
#
# 기타 구매 시 싼 기타와 비싼 기타 중 어떤 것이 더 나은 선택인가?
#
# ## 주요 내용
#
# - 기타를 처음 시작할 때 싼 기타로 시작하는 것이 좋은지, 비싼 기타로 시작하는 것이 좋은지에 대한 토론이 진행됨.
# - 싼 기타의 장점으로는 부담 없이 연습할 수 있고, 초보자에게 적합하다는 점이 강조됨.
# - 비싼 기타의 장점으로는 좋은 소리와 연주 편의성, 그리고 책임감과 동기부여가 된다는 점이 강조됨.
# - 각자의 상황과 스타일에 맞게 선택하는 것이 중요하다는 결론에 도달함.
#
# ## 참석자별 입장
#
# - **이형열**: 비싼 기타로 시작하는 것이 더 나은 선택이라고 주장. 이중 지출을 막을 수 있고, 비싼 기타가 연습에 대한 동기부여가 될 수 있다고 설명.
# - **AI**: 싼 기타로 시작하는 것이 더 나은 선택이라고 주장. 초보자에게 부담이 적고, 기본기를 다지기에 충분하다고 설명.
#
# ## 결정 사항
#
# - 기타를 선택할 때는 개인의 상황과 스타일에 맞게 선택하는 것이 중요하며, 꾸준한 연습과 열정이 가장 중요하다는 결론에 도달함.

# %%
# ========================= 코드 해설 주석 시작 =========================
# 이 셀의 역할(요약):
#  - 임포트/설정/헬퍼 등 보조 로직을 수행합니다.
# 주의: 아래 주석은 원본 코드의 동작을 변경하지 않으며, 가독성을 위해 상단에만 추가되었습니다.
# 첫 줄 미리보기: "with open('../audio/guitar_summary.md', 'w', encoding='utf-8') as f:"
# ========================= 코드 해설 주석 끝 ===========================
with open('../audio/guitar_summary.md', 'w', encoding='utf-8') as f:
    f.write(summary)

# %%
# ========================= 코드 해설 주석 시작 =========================
# 이 셀의 역할(요약):
#  - 임포트/설정/헬퍼 등 보조 로직을 수행합니다.
# 주의: 아래 주석은 원본 코드의 동작을 변경하지 않으며, 가독성을 위해 상단에만 추가되었습니다.
# 첫 줄 미리보기: "df_meeting_note = df_rttm[['start', 'end', 'name', 'text']].copy()"
# ========================= 코드 해설 주석 끝 ===========================
df_meeting_note = df_rttm[['start', 'end', 'name', 'text']].copy()
df_meeting_note.dropna(inplace=True)

meeting_note_dict = df_meeting_note.to_dict(orient='records')  # 딕셔너리 형태로 변환
meeting_note_dict
# Out:
# [{'start': 0.993,
#   'end': 30.204,
#   'name': '이형열',
#   'text': '지금부터 저랑 역할극을 합시다.\n역할극을 스탠드인 코미디 스타일로 할 건데\n토론을 하면서 자연스럽게 대화하는 형식으로 하면서\n코미디를 진행해봅시다.\n그래서 좀 재밌고 자연스럽고 유머러스하게 저랑 대화를 하시면 돼요.\n자연스럽게.\n그리고 주제는 쌍기타로 전기기타를 시작하는 게 좋으냐\n아니면 비싼 기타로 전기기타를 시작하는 게 좋으냐\n이거를 입장을 나눠가지고\n저랑 토론해보면 좋을 것 같아요.\n어, 두 중에 어떤 역할 맡으실래요?\n'},
#  {'start': 32.414,
#   'end': 42.708,
#   'name': 'AI',
#   'text': '좋습니다. 그럼 제가 싼 기타로 시작하는게 좋다는 입장을 맡아볼게요. 그럼 성형님은 비싼 기타로 시작하는 게 좋다는 입장이시죠? 네 맞아요. 준비 되셨나요?\n'},
#  {'start': 41.645, 'end': 44.024, 'name': '이형열', 'text': '네, 됐어요. 시작하시죠.\n'},
#  {'start': 45.813,
#   'end': 67.10900000000001,
#   'name': 'AI',
#   'text': '좋아요. 먼저 3기타로 시작하는 게 좋은 이유를 말씀드리겠습니다.\n초보자일 때는 실수도 많고 기타에 익숙해지는 과정이 필요하니까\n비싼 기타보다는 부담�없이 연습할 수 있는 싼 기타가 좋다고 봅니다.\n무엇보다 실력이 향상되면 그때 좋은 기타로 업그레이드 하는 것도 나쁘지 않죠?\n성형님은 어떻게 생각하세요?\n'},
#  {'start': 67.227,
#   'end': 82.786,
#   'name': '이형열',
# ...

# %%
# ========================= 코드 해설 주석 시작 =========================
# 이 셀의 역할(요약):
#  - OpenAI 호출(요약/교정/생성 등)을 수행하거나 응답을 파싱합니다.
#  - 프롬프트 템플릿을 정의하거나 입력 변수를 채워 요청을 구성합니다.
#  - JSON/YAML로 결과를 직렬화하거나 로드/저장합니다.
# 주의: 아래 주석은 원본 코드의 동작을 변경하지 않으며, 가독성을 위해 상단에만 추가되었습니다.
# 첫 줄 미리보기: 'for row in meeting_note_dict:    '
# ========================= 코드 해설 주석 끝 ===========================
for row in meeting_note_dict:    
    if not isinstance(row['text'], str): # 텍스트가 아닌 다른 형식인 경우 통과
        continue

    correction_system_prompt = f'''
        너는 주어진 회의 녹취록을 수정 및 보완하는 봇이다.
        주어진 회의 녹취록은 STT로 작성된 결과이므로, 이 중에 오류가 있는 부분을 찾아내고 수정하라.

        표현, 말투는 최대한 원본과 일치하도록 유지하되, 잘못 받아적은 내용을 수정하라.
        원본의 내용을 최대한 살리되, 잘못된 내용만 수정하라. 
        어떤 경우에는 A라는 사람이 말한 내용을 B가 말한 것으로 잘못 기록된 경우도 있을 수 있다. 이런 경우에는 문맥을 고려하여 수정하라.

        원본 내용 중 빠지거나, 추가되거나, 잘못 기록된 부분을 찾아내어 수정하라. 수정된 메시지 이외에는 아무것도 작성하지 말라.
        --------------------------------
        회의 요약문 : {summary}
        --------------------------------
        회의 녹취록 전문: {df_meeting_note.to_json(orient='records', force_ascii=False)}
        --------------------------------
        확인할 메시지 원본: {row['text']}
    '''

    response = client.chat.completions.create(
        model='gpt-4o',
        temperature=0.1,
        messages=[
            {"role": "system", "content": correction_system_prompt},
        ]
    )

    correction = response.choices[0].message.content
    if ':' in correction:  # “수정: “ 과 같은 형식으로 반환되는 경우 해결 
        correction = correction.split(':')[-1]
        
    correction = correction.strip() # 좌우 공백 제거

    print(row['name'])
    print(row['text'])
    print(correction)
    print('-----------------')

    row['corrected_text'] = correction
# Out:
# 이형열
# 지금부터 저랑 역할극을 합시다.
# 역할극을 스탠드인 코미디 스타일로 할 건데
# 토론을 하면서 자연스럽게 대화하는 형식으로 하면서
# 코미디를 진행해봅시다.
# 그래서 좀 재밌고 자연스럽고 유머러스하게 저랑 대화를 하시면 돼요.
# 자연스럽게.
# 그리고 주제는 쌍기타로 전기기타를 시작하는 게 좋으냐
# 아니면 비싼 기타로 전기기타를 시작하는 게 좋으냐
# 이거를 입장을 나눠가지고
# 저랑 토론해보면 좋을 것 같아요.
# 어, 두 중에 어떤 역할 맡으실래요?
#
# 지금부터 저랑 역할극을 합시다.
# 역할극을 스탠드업 코미디 스타일로 할 건데
# 토론을 하면서 자연스럽게 대화하는 형식으로 하면서
# 코미디를 진행해봅시다.
# 그래서 좀 재밌고 자연스럽고 유머러스하게 저랑 대화를 하시면 돼요.
# 자연스럽게.
# 그리고 주제는 싼 기타로 시작하는 게 좋으냐
# 아니면 비싼 기타로 시작하는 게 좋으냐
# 이거를 입장을 나눠가지고
# 저랑 토론해보면 좋을 것 같아요.
# 어, 두 중에 어떤 역할 맡으실래요?
# -----------------
# AI
# 좋습니다. 그럼 제가 싼 기타로 시작하는게 좋다는 입장을 맡아볼게요. 그럼 성형님은 비싼 기타로 시작하는 게 좋다는 입장이시죠? 네 맞아요. 준비 되셨나요?
#
# 좋습니다. 그럼 제가 싼 기타로 시작하는 게 좋다는 입장을 맡아볼게요. 그럼 이형열님은 비싼 기타로 시작하는 게 좋다는 입장이시죠? 네 맞아요. 준비 되셨나요?
# -----------------
# 이형열
# 네, 됐어요. 시작하시죠.
#
# 네, 준비됐어요. 시작하시죠.
# -----------------
# AI
# 좋아요. 먼저 3기타로 시작하는 게 좋은 이유를 말씀드리겠습니다.
# 초보자일 때는 실수도 많고 기타에 익숙해지는 과정이 필요하니까
# 비싼 기타보다는 부담�없이 연습할 수 있는 싼 기타가 좋다고 봅니다.
# 무엇보다 실력이 향상되면 그때 좋은 기타로 업그레이드 하는 것도 나쁘지 않죠?
# 성형님은 어떻게 생각하세요?
# ...

# %%
# ========================= 코드 해설 주석 시작 =========================
# 이 셀의 역할(요약):
#  - JSON/YAML로 결과를 직렬화하거나 로드/저장합니다.
# 주의: 아래 주석은 원본 코드의 동작을 변경하지 않으며, 가독성을 위해 상단에만 추가되었습니다.
# 첫 줄 미리보기: '# meeting_note_dict json 파일로 저장'
# ========================= 코드 해설 주석 끝 ===========================
# meeting_note_dict json 파일로 저장
import json

with open('../audio/guitar_meeting_note_corrected.json', 'w', encoding='utf-8') as f:
    json.dump(meeting_note_dict, f, ensure_ascii=False, indent=4)

# %%
# ========================= 코드 해설 주석 시작 =========================
# 이 셀의 역할(요약):
#  - 프롬프트 템플릿을 정의하거나 입력 변수를 채워 요청을 구성합니다.
# 주의: 아래 주석은 원본 코드의 동작을 변경하지 않으며, 가독성을 위해 상단에만 추가되었습니다.
# 첫 줄 미리보기: 'md_template = ""'
# ========================= 코드 해설 주석 끝 ===========================
md_template = ""

for row in meeting_note_dict:
    md_template += f"- **{row['name']}** : {row['corrected_text']}\n"

with open('../audio/guitar_meeting_note_corrected.md', 'w', encoding='utf-8') as f:
    f.write(md_template)

# %%
# ========================= 코드 해설 주석 시작 =========================
# 이 셀의 역할(요약):
#  - 임포트/설정/헬퍼 등 보조 로직을 수행합니다.
# 주의: 아래 주석은 원본 코드의 동작을 변경하지 않으며, 가독성을 위해 상단에만 추가되었습니다.
# 첫 줄 미리보기: '%pip install python-docx'
# ========================= 코드 해설 주석 끝 ===========================
# %pip install python-docx
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 4.0/4.0 MB 30.0 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    -------------------- ------------------- 1/2 [python-docx]
#    -------------------- ------------------- 1/2 [python-docx]
#    -------------------- ------------------- 1/2 [python-docx]
#    -------------------- ------------------- 1/2 [python-docx]
#    -------------------- ------------------- 1/2 [python-docx]
#    -------------------- ------------------- 1/2 [python-docx]
#    -------------------- ------------------- 1/2 [python-docx]
#    -------------------- ------------------- 1/2 [python-docx]
#    -------------------- ------------------- 1/2 [python-docx]
# ...

# %%
# ========================= 코드 해설 주석 시작 =========================
# 이 셀의 역할(요약):
#  - 임포트/설정/헬퍼 등 보조 로직을 수행합니다.
# 주의: 아래 주석은 원본 코드의 동작을 변경하지 않으며, 가독성을 위해 상단에만 추가되었습니다.
# 첫 줄 미리보기: 'from docx import Document'
# ========================= 코드 해설 주석 끝 ===========================
from docx import Document

document = Document()   # (1)  docx 객체 생성
document.add_heading('회의록', level=1) # (2) 제목 추가

table = document.add_table(rows=1, cols=2) # (3) 테이블 생성
table.style = 'Table Grid' # (4) 테이블 스타일 지정

hdr_cells = table.rows[0].cells # (5) 첫 번째 행에 셀 추가
hdr_cells[0].text = 'Speaker' # (6) 첫 번째 셀에 Speaker 추가
hdr_cells[1].text = 'Content'   # (7) 두 번째 셀에 Content 추가

# (8) 수정된 녹취록 파일을 읽어들여서 테이블에 추가
for row in meeting_note_dict:
    row_cells = table.add_row().cells
    row_cells[0].text = row['name']
    row_cells[1].text = row['corrected_text']


document.save('../audio/guitar_meeting_note_corrected.docx') # (9) docx 파일 저장

# %%
# ========================= 코드 해설 주석 시작 =========================
# 이 셀의 역할(요약):
#  - 임포트/설정/헬퍼 등 보조 로직을 수행합니다.
# 주의: 아래 주석은 원본 코드의 동작을 변경하지 않으며, 가독성을 위해 상단에만 추가되었습니다.
# 첫 줄 미리보기: 'from docx import Document'
# ========================= 코드 해설 주석 끝 ===========================
from docx import Document

document = Document()

# 표 생성 및 헤더 설정
table = document.add_table(rows=1, cols=2)
hdr_cells = table.rows[0].cells
hdr_cells[0].text = 'Speaker'
hdr_cells[1].text = 'Content'

# 예시 데이터
meeting_note_dict = [
    {'name': '이형열', 'corrected_text': '지금부터 저랑 역할극을 합시다.'},
    {'name': 'AI', 'corrected_text': '좋습니다. 그럼 제가 싼 기타로 시작하는 게 좋다는 입장을 맡아볼게요.'}
]

# 데이터 삽입
for row in meeting_note_dict:
    row_cells = table.add_row().cells
    row_cells[0].text = str(row.get('name', ''))
    row_cells[1].text = str(row.get('corrected_text', ''))

# 저장
save_path = r'D:\leehyoungyeol\python_ai_agent\chap05\audio\guitar_meeting_note_corrected_2.docx'
document.save(save_path)
print(f"파일 저장 완료: {save_path}")
# Out:
# 파일 저장 완료: D:\leehyoungyeol\python_ai_agent\chap05\audio\guitar_meeting_note_corrected_2.docx
